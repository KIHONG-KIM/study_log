# %% [markdown]
# <a href="https://colab.research.google.com/github/KIHONG-KIM/study_log/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%A0%95%EC%A0%9C_%ED%95%A8%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: 파이썬에서 가장 사용도가 높은 데이터 정제 관련함수 100가지 알려줘

1. `isnull()`: Check for null values.
2. `notnull()`: Check for non-null values.
3. `fillna()`: Replace null values with a specified value.
4. `dropna()`: Remove rows with null values.
5. `astype()`: Convert data types.
6. `to_string()`: Convert data to a string representation.
7. `to_frame()`: Convert a series to a DataFrame.
8. `to_dict()`: Convert a DataFrame to a dictionary.
9. `head()`: View the first few rows of a DataFrame.
10. `tail()`: View the last few rows of a DataFrame.
11. `info()`: Get summary information about a DataFrame.
12. `describe()`: Calculate descriptive statistics for a DataFrame.
13. `value_counts()`: Count the number of times each unique value occurs in a Series.
14. `unique()`: Return unique values in a Series or DataFrame.
15. `nunique()`: Count the number of unique values in a Series or DataFrame.
16. `duplicated()`: Find duplicate rows in a DataFrame.
17. `drop_duplicates()`: Remove duplicate rows from a DataFrame.
18. `rename()`: Rename columns or rows in a DataFrame.
19. `set_index()`: Set a new index for a DataFrame.
20. `reset_index()`: Reset the index of a DataFrame.
21. `sort_values()`: Sort a DataFrame by one or more columns.
22. `sort_index()`: Sort a DataFrame by its index.
23. `groupby()`: Group a DataFrame by one or more columns.
24. `agg()`: Apply aggregation functions to a DataFrame.
25. `transform()`: Apply a function to each row or column of a DataFrame.
26. `apply()`: Apply a function to each element of a Series or DataFrame.
27. `map()`: Apply a function to each element of a Series or DataFrame.
28. `filter()`: Filter rows from a DataFrame based on a condition.
29. `query()`: Filter rows from a DataFrame using a boolean expression.
30. `merge()`: Join two DataFrames on one or more keys.
31. `join()`: Join two DataFrames on one or more keys.
32. `concat()`: Concatenate two or more DataFrames.
33. `append()`: Append rows to a DataFrame.
34. `assign()`: Add new columns to a DataFrame.
35. `insert()`: Insert a new column into a DataFrame.
36. `delete()`: Delete a column from a DataFrame.
37. `pop()`: Remove and return a column from a DataFrame.
38. `reindex()`: Reindex a DataFrame.
39. `set_value()`: Set the value of a single element in a DataFrame.
40. `get_value()`: Get the value of a single element in a DataFrame.
41. `loc[]`: Select rows and columns by label.
42. `iloc[]`: Select rows and columns by integer location.
43. `ix[]`: Select rows and columns by label or integer location.
44. `at[]`: Access a single element by label.
45. `iat[]`: Access a single element by integer location.
46. `where()`: Select elements from a DataFrame based on a condition.
47. `mask()`: Select elements from a DataFrame based on a condition.
48. `clip()`: Limit the values in a DataFrame to a specified range.
49. `round()`: Round the values in a DataFrame to a specified number of decimal places.
50. `floor()`: Round the values in a DataFrame down to the nearest integer.
51. `ceil()`: Round the values in a DataFrame up to the nearest integer.
52. `abs()`: Calculate the absolute value of the values in a DataFrame.
53. `pow()`: Calculate the power of the values in a DataFrame.
54. `exp()`: Calculate the exponential of the values in a DataFrame.
55. `log()`: Calculate the logarithm of the values in a DataFrame.
56. `log10()`: Calculate the base-10 logarithm of the values in a DataFrame.
57. `log2()`: Calculate the base-2 logarithm of the values in a DataFrame.
58. `sin()`: Calculate the sine of the values in a DataFrame.
59. `cos()`: Calculate the cosine of the values in a DataFrame.
60. `tan()`: Calculate the tangent of the values in a DataFrame.
61. `arcsin()`: Calculate the inverse sine of the values in a DataFrame.
62. `arccos()`: Calculate the inverse cosine of the values in a DataFrame.
63. `arctan()`: Calculate the inverse tangent of the values in a DataFrame.
64. `sinh()`: Calculate the hyperbolic sine of the values in a DataFrame.
65. `cosh()`: Calculate the hyperbolic cosine of the values in a DataFrame.
66. `tanh()`: Calculate the hyperbolic tangent of the values in a DataFrame.
67. `arcsinh()`: Calculate the inverse hyperbolic sine of the values in a DataFrame.
68. `arccosh()`: Calculate the inverse hyperbolic cosine of the values in a DataFrame.
69. `arctanh()`: Calculate the inverse hyperbolic tangent of the values in a DataFrame.
70. `deg2rad()`: Convert degrees to radians.
71. `rad2deg()`: Convert radians to degrees.
72. `isfinite()`: Check if values are finite.
73. `isinf()`: Check if values are infinite.
74. `isnan()`: Check if values are NaN.
75. `to_datetime()`: Convert strings to datetime objects.
76. `to_timedelta()`: Convert strings to timedelta objects.
77. `to_numeric()`: Convert strings to numeric objects.
78. `to_categorical()`: Convert categorical data to a categorical type.
79. `get_dummies()`: Create dummy variables for categorical data.
80. `cut()`: Bin values into discrete intervals.
81. `qcut()`: Bin values into quantiles.
82. `rank()`: Calculate the rank of each value in a Series or DataFrame.
83. `pct_change()`: Calculate the percentage change between consecutive values.
84. `cumsum()`: Calculate the cumulative sum of values.
85. `cumprod()`: Calculate the cumulative product of values.
86. `cummin()`: Calculate the cumulative minimum of values.
87. `cummax()`: Calculate the cumulative maximum of values.
88. `diff()`: Calculate the difference between consecutive values.
89. `shift()`: Shift values by a specified number of periods.
90. `rolling()`: Create a rolling window for calculating statistics.
91. `expanding()`: Create an expanding window for calculating statistics.
92. `ewm()`: Create an exponentially weighted window for calculating statistics.
93. `corr()`: Calculate the correlation between two Series or DataFrames.
94. `cov()`: Calculate the covariance between two Series or DataFrames.
95. `corrwith()`: Calculate the correlation between a Series and a DataFrame.
96. `covwith()`: Calculate the covariance between a Series and a DataFrame.
97. `isna()`: Check for missing values.
98. `notna()`: Check for non-missing values.
99. `dropna()`: Remove missing values.
100. `fillna()`: Fill missing values.
